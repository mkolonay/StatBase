# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

a = [0,1,2,3,4]
b = [.44,.36,.15,.04,.01]

labels = ['1', '2', '3', '4','5']
men_means = a
women_means = b

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Democratic')
rects2 = ax.bar(x + width/2, women_means, width, label='Republican')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Dollars Spent')
ax.set_title('Dollars Spent by Party in Home District')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
fig.patch.set_facecolor('xkcd:white')

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

a_label = 'legend'
a = [.44,.36,.15,.04,.01]
labels = ['1', '2', '3', '4','5']

x = np.arange(len(labels))  # the label locations
print(x)
width = 0.5  # the width of the bars

fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/2, a, width, label=a_label)
print(rects1[0])
print(rects1[1])
print(rects1[2])


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Some label 1')
ax.set_title('Some label 2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 0),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
fig.tight_layout()
fig.patch.set_facecolor('xkcd:white')

plt.show()
# Out:
# [0 1 2 3 4]
# Rectangle(xy=(-0.25, 0), width=0.5, height=0.44, angle=0)
# Rectangle(xy=(0.75, 0), width=0.5, height=0.36, angle=0)
# Rectangle(xy=(1.75, 0), width=0.5, height=0.15, angle=0)
