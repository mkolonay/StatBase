# %%
from stat_base import MyStats

# %% [markdown]
# <img src="images\6\2_5.PNG" width="500" height="600">
# <img src="images\6\2_5_a.PNG" width="500" height="600">

# %%
_mu = 30
_sigma = 5 
MyStats.ZValues.Normal.Population.get_z_value(x=25, mu=_mu, sigma=_sigma)
MyStats.ZValues.Normal.Population.get_z_value(x=42, mu=_mu, sigma=_sigma)
MyStats.ZValues.Normal.Population.get_x_value(z=-2, mu=_mu, sigma=_sigma)
MyStats.ZValues.Normal.Population.get_x_value(z=1.3, mu=_mu, sigma=_sigma)

# %% [markdown]
# <img src="images\6\2_11.PNG" width="500" height="600">
# <img src="images\6\2_11_a.PNG" width="500" height="600">

# %%
MyStats.ZValues.Normal.Population.get_z_value(x=4.2, mu=4.8, sigma=0.3)
# Out:
# $ z = \frac{x - \mu}{\sigma} = \frac{4.2 - 4.8}{0.3} = -2.0 $
# -2.0

# %% [markdown]
# <img src="images\6\2_13-36.PNG" width="500" height="600">
# <img src="images\6\2_13-36_a.PNG" width="500" height="600">

# %%
MyStats.Probability.Normal.Population.get_gte_x(x=0, mu=0, sigma=1, round_p=4)
                # type == 'left'
                # type == 'right'
                # type == 'two'
                # type == 'between'
MyStats.Graphs.Normal.showGraph(z_values=[0], type='right')
# Out:
# $ P(x \geq 0) $
# $ z = \frac{x - \mu}{\sigma} = \frac{0 - 0}{1} = 0.0 $
# $ P(x \geq 0) = P(z \geq 0.0) = 1 - P(z < 0.0) = 1-0.5 = 0.5 $

# %%
z_value = MyStats.Probability.Normal.Population.get_lte_x(x=-.13, mu=0, sigma=1, round_p=4)[0]
                # type == 'left'
                # type == 'right'
                # type == 'two'
                # type == 'between'
MyStats.Graphs.Normal.showGraph(z_values=[z_value], type='right')
# Out:
# $ P(x \leq -0.13) $
# $ z = \frac{x - \mu}{\sigma} = \frac{-0.13 - 0}{1} = -0.13 $
# $ P(x \leq -0.13) = 0.4483 $
